# %% [markdown]
# <a href="https://colab.research.google.com/github/Cirediallo/DL-for-Computer-Vision-Michigan/blob/main/knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EECS 498-007/598-005 Assignment 1-2: K-Nearest Neighbors (k-NN)
#
# Before we start, please put your name and UMID in following format
#
# : Firstname LASTNAME, #00000000   //   e.g.) Justin JOHNSON, #12345678

# %% [markdown]
# **Your Answer:**
# DIALLO, #XXXXXXXX

# %% [markdown]
# In this notebook you will implement a K-Nearest Neighbors classifier on the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# Recall that the K-Nearest Neighbor classifier does the following:
# - During training, the classifier simply memorizes the training data
# - During testing, test images are compared to each training image; the predicted label is the majority vote among the K nearest training examples.
#
# After implementing the K-Nearest Neighbor classifier, you will use *cross-validation* to find the best value of K.
#
# The goals of this exercise are to go through a simple example of the data-driven image classification pipeline, and also to practice writing efficient, vectorized code in [PyTorch](https://pytorch.org/).

# %% [markdown]
# # Setup Code
# Before getting started we need to run some boilerplate code to set up our environment. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the [autoreload](https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html?highlight=autoreload) extension. This allows us to edit `.py` source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the folowing cell should print the filenames from the assignment:
#
# ```
# ['pytorch101.py', 'knn.py', 'knn.ipynb', 'eecs598', 'pytorch101.ipynb']
# ```

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A1 folder, then '2020FA/A1'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2020FA/A1'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '/content/drive/MyDrive/A1'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['pytorch101.ipynb', 'pytorch101.py', 'knn.ipynb', 'eecs598', '__pycache__', 'knn.py']

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run th following cell to allow us to import from the `.py` files of this assignment. If it works correctly, it should print the message:
#
# ```
# Hello from knn.py!
# ```
#
# as well as the last edit time for the file `knn.py`.

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

from knn import hello
hello()

knn_path = os.path.join(GOOGLE_DRIVE_PATH, 'knn.py')
knn_edit_time = time.ctime(os.path.getmtime(knn_path))
print('knn.py last edited on %s' % knn_edit_time)
# Out:
# Hello from knn.py!
# knn.py last edited on Fri Nov 10 10:38:41 2023

# %% [markdown]
# # Data preprocessing / Visualization

# %% [markdown]
# ## Setup code
# Run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
import eecs598
import torch
import torchvision
import matplotlib.pyplot as plt
import statistics

plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16

# %% [markdown]
# ## Load the CIFAR-10 dataset
# The utility function `eecs598.data.cifar10()` returns the entire CIFAR-10 dataset as a set of four **Torch tensors**:
#
# - `x_train` contains all training images (real numbers in the range $[0, 1]$)
# - `y_train` contains all training labels (integers in the range $[0, 9]$)
# - `x_test` contains all test images
# - `y_test` contains all test labels
#
# This function automatically downloads the CIFAR-10 dataset the first time you run it.

# %%
x_train, y_train, x_test, y_test = eecs598.data.cifar10()

print('Training set:', )
print('  data shape:', x_train.shape)
print('  labels shape: ', y_train.shape)
print('Test set:')
print('  data shape: ', x_test.shape)
print('  labels shape', y_test.shape)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 48390659.11it/s]
# Extracting ./cifar-10-python.tar.gz to .
# Training set:
#   data shape: torch.Size([50000, 3, 32, 32])
#   labels shape:  torch.Size([50000])
# Test set:
#   data shape:  torch.Size([10000, 3, 32, 32])
#   labels shape torch.Size([10000])

# %% [markdown]
# ## Visualize the dataset
# To give you a sense of the nature of the images in CIFAR-10, this cell visualizes some random examples from the training set.

# %%
import random
from torchvision.utils import make_grid

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
samples_per_class = 12
samples = []
for y, cls in enumerate(classes):
    plt.text(-4, 34 * y + 18, cls, ha='right')
    idxs, = (y_train == y).nonzero(as_tuple=True)
    for i in range(samples_per_class):
        idx = idxs[random.randrange(idxs.shape[0])].item()
        samples.append(x_train[idx])
img = torchvision.utils.make_grid(samples, nrow=samples_per_class)
plt.imshow(eecs598.tensor_to_image(img))
plt.axis('off')
plt.show()

# %% [markdown]
# ## Subsample the dataset
# When implementing machine learning algorithms, it's usually a good idea to use a small sample of the full dataset. This way your code will run much faster, allowing for more interactive and efficient development. Once you are satisfied that you have correctly implemented the algorithm, you can then rerun with the entire dataset.
#
# The function `eecs598.data.cifar10()` can automatically subsample the CIFAR10 dataset for us. To see how to use it, we can check the documentation using the built-in `help` command:

# %%
help(eecs598.data.cifar10)
# Out:
# Help on function cifar10 in module eecs598.data:
#
# cifar10(num_train=None, num_test=None, x_dtype=torch.float32)
#     Return the CIFAR10 dataset, automatically downloading it if necessary.
#     This function can also subsample the dataset.
#
#     Inputs:
#     - num_train: [Optional] How many samples to keep from the training set.
#       If not provided, then keep the entire training set.
#     - num_test: [Optional] How many samples to keep from the test set.
#       If not provided, then keep the entire test set.
#     - x_dtype: [Optional] Data type of the input image
#
#     Returns:
#     - x_train: `x_dtype` tensor of shape (num_train, 3, 32, 32)
#     - y_train: int64 tensor of shape (num_train, 3, 32, 32)
#     - x_test: `x_dtype` tensor of shape (num_test, 3, 32, 32)
#     - y_test: int64 tensor of shape (num_test, 3, 32, 32)

# %% [markdown]
# We will subsample the data to use only 500 training examples and 250 test examples:

# %%
num_train = 500
num_test = 250

x_train, y_train, x_test, y_test = eecs598.data.cifar10(num_train, num_test)

print('Training set:', )
print('  data shape:', x_train.shape)
print('  labels shape: ', y_train.shape)
print('Test set:')
print('  data shape: ', x_test.shape)
print('  labels shape', y_test.shape)
# Out:
# Training set:
#   data shape: torch.Size([500, 3, 32, 32])
#   labels shape:  torch.Size([500])
# Test set:
#   data shape:  torch.Size([250, 3, 32, 32])
#   labels shape torch.Size([250])

# %% [markdown]
# # K-Nearest Neighbors (k-NN)

# %% [markdown]
# ## Compute distances: Naive implementation
# Now that we have examined and prepared our data, it is time to implement the kNN classifier. We can break the process down into two steps:
#
# 1. Compute the (squared Euclidean) distances between all training examples and all test examples
# 2. Given these distances, for each test example find its k nearest neighbors and have them vote for the label to output
#
# Lets begin with computing the distance matrix between all training and test examples. First we will implement a naive version of the distance computation, using explicit loops over the training and test sets. In the file `knn.py`, implement the function `compute_distances_two_loops`.
#
# **NOTE: When implementing distance functions for this assignment, you may not use functions `torch.norm` or `torch.dist` (or their instance method variants `x.norm` / `x.dist`); you may not use any functions from `torch.nn` or `torch.nn.functional`.**

# %%
from knn import compute_distances_two_loops

torch.manual_seed(0)
num_train = 500
num_test = 250
x_train, y_train, x_test, y_test = eecs598.data.cifar10(num_train, num_test)

dists = compute_distances_two_loops(x_train, x_test)
print('dists has shape: ', dists.shape)
# Out:
# dists has shape:  torch.Size([500, 250])

# %% [markdown]
# As a visual debugging step, we can visualize the distance matrix, where each row is a test example and each column is a training example.

# %%
plt.imshow(dists.numpy(), cmap='gray', interpolation='none')
plt.colorbar()
plt.xlabel('test')
plt.ylabel('train')
plt.show()

# %% [markdown]
# ## Compute distances: Vectorization
# Our implementation of the distance computation above is fairly inefficient since it uses nested Python loops over the training and test sets.
#
# When implementing algorithms in PyTorch, it's best to avoid loops in Python if possible. Instead it is preferable to implement your computation so that all loops happen inside PyTorch functions. This will usually be much faster than writing your own loops in Python, since PyTorch functions can be internally optimized to iterate efficiently, possibly using multiple threads. This is especially important when using a GPU to accelerate your code.
#
# The process of eliminating explict loops from your code is called **vectorization**. Sometimes it is straighforward to vectorize code originally written with loops; other times vectorizing requires thinking about the problem in a new way. We will use vectorization to improve the speed of our distance computation function.
#
# As a first step toward vectorizing our distance computation, you will implement a version that uses only a single Python loop over the training data. In the file `knn.py`, complete the implementation of the function `compute_distances_one_loop`.
#
# We can check the correctness of our one-loop implementation by comparing it with our two-loop implementation on some randomly generated data.
#
# Note that we do the comparison with 64-bit floating points for increased numeric precision.

# %%
from knn import compute_distances_one_loop
from knn import compute_distances_two_loops

torch.manual_seed(0)
x_train_rand = torch.randn(100, 3, 16, 16, dtype=torch.float64)
x_test_rand = torch.randn(100, 3, 16, 16, dtype=torch.float64)

dists_one = compute_distances_one_loop(x_train_rand, x_test_rand)
dists_two = compute_distances_two_loops(x_train_rand, x_test_rand)
difference = (dists_one - dists_two).pow(2).sum().sqrt().item()
print('Difference: ', difference)
if difference < 1e-4:
    print('Good! The distance matrices match')
else:
    print('Uh-oh! The distance matrices are different')
# Out:
# Difference:  0.0
# Good! The distance matrices match

# %% [markdown]
# You will now implement a fully vectorized version of the distance computation function
# that does not use any Python loops. In the file `knn.py`, implement the function `compute_distances_no_loops`.
#
# As before, we can check the correctness of our implementation by comparing the fully vectorized version against the original naive version:

# %%
from knn import compute_distances_two_loops
from knn import compute_distances_no_loops

torch.manual_seed(0)
x_train_rand = torch.randn(100, 3, 16, 16, dtype=torch.float64)
x_test_rand = torch.randn(100, 3, 16, 16, dtype=torch.float64)

dists_two = compute_distances_two_loops(x_train_rand, x_test_rand)
dists_none = compute_distances_no_loops(x_train_rand, x_test_rand)
difference = (dists_two - dists_none).pow(2).sum().sqrt().item()
print('Difference: ', difference)
if difference < 1e-4:
  print('Good! The distance matrices match')
else:
  print('Uh-oh! The distance matrices are different')
# Out:
# x_train vectorization shape:  torch.Size([100, 1, 768])
# x_test vectorization shape:  torch.Size([1, 100, 768])
# squared_diff shape:  torch.Size([100, 100, 768])
# Difference:  0.0
# Good! The distance matrices match

# %% [markdown]
# We can now compare the speed of our three implementations. If you've implemented everything properly, the one-loop implementation should take less than 4 seconds to run, and the fully vectorized implementation should take less than 0.1 seconds to run.

# %%
import time
from knn import compute_distances_two_loops
from knn import compute_distances_one_loop
from knn import compute_distances_no_loops

def timeit(f, *args):
    tic = time.time()
    f(*args)
    toc = time.time()
    return toc - tic

torch.manual_seed(0)
x_train_rand = torch.randn(500, 3, 32, 32)
x_test_rand = torch.randn(500, 3, 32, 32)

two_loop_time = timeit(compute_distances_two_loops, x_train_rand, x_test_rand)
print('Two loop version took %.2f seconds' % two_loop_time)

one_loop_time = timeit(compute_distances_one_loop, x_train_rand, x_test_rand)
speedup = two_loop_time / one_loop_time
print('One loop version took %.2f seconds (%.1fX speedup)'
      % (one_loop_time, speedup))

no_loop_time = timeit(compute_distances_no_loops, x_train_rand, x_test_rand)
speedup = two_loop_time / no_loop_time
print('No loop version took %.2f seconds (%.1fX speedup)'
      % (no_loop_time, speedup))
# Out:
# Two loop version took 7.90 seconds
# One loop version took 0.74 seconds (10.6X speedup)
# x_train vectorization shape:  torch.Size([500, 1, 3072])
# x_test vectorization shape:  torch.Size([1, 500, 3072])
# squared_diff shape:  torch.Size([500, 500, 3072])
# No loop version took 4.00 seconds (2.0X speedup)

# %% [markdown]
# ## Predict labels
# Now that we have a method for computing distances between training and test examples, we need to implement a function that uses those distances together with the training labels to predict labels for test samples.
#
# In the file `knn.py`, implement the function `predict_labels`.

# %%
from knn import predict_labels

torch.manual_seed(0)
dists = torch.tensor([
    [0.3, 0.4, 0.1],
    [0.1, 0.5, 0.5],
    [0.4, 0.1, 0.2],
    [0.2, 0.2, 0.4],
    [0.5, 0.3, 0.3],
])

y_train = torch.tensor([0, 1, 0, 1, 2])
y_pred_expected = torch.tensor([1, 0, 0])
y_pred = predict_labels(dists, y_train, k=3)
correct = y_pred.tolist() == y_pred_expected.tolist()
print('Correct: ', correct)
# Out:
# K first indices  tensor([1, 3, 0])
# nearest labels:  tensor([1, 1, 0])
# label occurrences:  tensor([1, 2])
# ==========================
# K first indices  tensor([2, 3, 4])
# nearest labels:  tensor([0, 1, 2])
# label occurrences:  tensor([1, 1, 1])
# ==========================
# K first indices  tensor([0, 2, 4])
# nearest labels:  tensor([0, 0, 2])
# label occurrences:  tensor([2, 0, 1])
# ==========================
# Correct:  True

# %% [markdown]
# Now we have implemented all the required functionality for the K-Nearest Neighbor classifier. In the file `knn.py`, complete the implementation of the `KnnClassifer` class.
#
# We can get some intuition into the KNN classifier by visualizing its predictions on toy 2D data. Here we will generate some random training and test points in 2D, and assign random labels to the training points. We can then make predictions for the test points, and visualize both training and test points. Training points are shown as stars, and tet points are shown as small transparent circles. The color of each point denots its label -- ground-truth label for training points, and predicted label for test points.

# %%
from knn import KnnClassifier

num_test = 10000
num_train = 20
num_classes = 5

# Generate random training and test data
torch.manual_seed(128)
x_train = torch.rand(num_train, 2)
y_train = torch.randint(num_classes, size=(num_train,))
x_test = torch.rand(num_test, 2)
classifier = KnnClassifier(x_train, y_train)
print("avant")
print(classifier.predict(x_test, k=5))
# Plot predictions for different values of k
for k in [1, 3, 5]:
    y_test = classifier.predict(x_test, k=k)
    print("shape y_test: ", y_test)
    plt.gcf().set_size_inches(8, 8)
    class_colors = ['r', 'g', 'b', 'k', 'y']
    train_colors = [class_colors[c] for c in y_train]
    test_colors = [class_colors[c] for c in y_test]
    plt.scatter(x_test[:, 0], x_test[:, 1],
                color=test_colors, marker='o', s=32, alpha=0.05)
    plt.scatter(x_train[:, 0], x_train[:, 1],
                color=train_colors, marker='*', s=128.0)
    plt.title('Predictions for k = %d' % k, size=16)
    plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([15])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([8])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([12])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([8])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([8])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([15])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([8])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([8])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([8])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([8])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([15])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([15])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([8])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([15])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([15])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([15])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([6])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([4])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([8])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([15])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([1])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([3])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([18])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([16])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([5])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([17])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([15])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([13])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([14])
# nearest labels:  tensor([4])
# label occurrences:  tensor([0, 0, 0, 0, 1])
# ==========================
# K first indices  tensor([2])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([9])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([10])
# nearest labels:  tensor([1])
# label occurrences:  tensor([0, 1])
# ==========================
# K first indices  tensor([7])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([11])
# nearest labels:  tensor([3])
# label occurrences:  tensor([0, 0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ==========================
# K first indices  tensor([0])
# nearest labels:  tensor([2])
# label occurrences:  tensor([0, 0, 1])
# ==========================
# K first indices  tensor([19])
# nearest labels:  tensor([0])
# label occurrences:  tensor([1])
# ...
# nearest labels:  tensor([2, 3, 1, 3, 0])
# label occurrences:  tensor([1, 1, 1, 2])
# ==========================
# K first indices  tensor([ 9,  7, 17,  8,  2])
# nearest labels:  tensor([2, 3, 3, 1, 1])
# label occurrences:  tensor([0, 2, 1, 2])
# ==========================
# K first indices  tensor([ 7,  2,  0,  9, 17])
# nearest labels:  tensor([3, 1, 2, 2, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([ 8, 11,  9, 17, 18])
# nearest labels:  tensor([1, 3, 2, 3, 0])
# label occurrences:  tensor([1, 1, 1, 2])
# ==========================
# K first indices  tensor([ 9,  7,  2, 17,  8])
# nearest labels:  tensor([2, 3, 1, 3, 1])
# label occurrences:  tensor([0, 2, 1, 2])
# ==========================
# K first indices  tensor([10,  5,  1, 15, 16])
# nearest labels:  tensor([1, 0, 2, 2, 1])
# label occurrences:  tensor([1, 2, 2])
# ==========================
# K first indices  tensor([18, 12, 11,  4, 13])
# nearest labels:  tensor([0, 0, 3, 2, 3])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([ 2,  0, 14,  6, 19])
# nearest labels:  tensor([1, 2, 4, 2, 0])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([11,  8, 18, 17,  9])
# nearest labels:  tensor([3, 1, 0, 3, 2])
# label occurrences:  tensor([1, 1, 1, 2])
# ==========================
# K first indices  tensor([13, 17,  4, 12, 18])
# nearest labels:  tensor([3, 3, 2, 0, 0])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([ 1, 15,  6, 14,  2])
# nearest labels:  tensor([2, 2, 2, 4, 1])
# label occurrences:  tensor([0, 1, 3, 0, 1])
# ==========================
# K first indices  tensor([19, 14,  0,  2, 15])
# nearest labels:  tensor([0, 4, 2, 1, 2])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([7, 3, 9, 8, 0])
# nearest labels:  tensor([3, 2, 2, 1, 2])
# label occurrences:  tensor([0, 1, 3, 1])
# ==========================
# K first indices  tensor([ 2,  0, 14,  6, 19])
# nearest labels:  tensor([1, 2, 4, 2, 0])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([ 0, 14,  2, 19,  6])
# nearest labels:  tensor([2, 4, 1, 0, 2])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([ 2, 14,  0, 19,  6])
# nearest labels:  tensor([1, 4, 2, 0, 2])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([ 1, 15, 10,  5,  6])
# nearest labels:  tensor([2, 2, 1, 0, 2])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([7, 3, 9, 8, 0])
# nearest labels:  tensor([3, 2, 2, 1, 2])
# label occurrences:  tensor([0, 1, 3, 1])
# ==========================
# K first indices  tensor([16,  5, 10,  6,  4])
# nearest labels:  tensor([1, 0, 1, 2, 2])
# label occurrences:  tensor([1, 2, 2])
# ==========================
# K first indices  tensor([17,  9, 13,  2,  8])
# nearest labels:  tensor([3, 2, 3, 1, 1])
# label occurrences:  tensor([0, 2, 1, 2])
# ==========================
# K first indices  tensor([17, 13,  4,  9, 12])
# nearest labels:  tensor([3, 3, 2, 2, 0])
# label occurrences:  tensor([1, 0, 2, 2])
# ==========================
# K first indices  tensor([7, 0, 9, 3, 8])
# nearest labels:  tensor([3, 2, 2, 2, 1])
# label occurrences:  tensor([0, 1, 3, 1])
# ==========================
# K first indices  tensor([18, 12,  4, 17, 11])
# nearest labels:  tensor([0, 0, 2, 3, 3])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([ 6,  2,  5, 14,  1])
# nearest labels:  tensor([2, 1, 0, 4, 2])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([ 2,  6, 14,  0, 17])
# nearest labels:  tensor([1, 2, 4, 2, 3])
# label occurrences:  tensor([0, 1, 2, 1, 1])
# ==========================
# K first indices  tensor([17, 13,  9,  8,  6])
# nearest labels:  tensor([3, 3, 2, 1, 2])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([17,  9,  8, 18, 12])
# nearest labels:  tensor([3, 2, 1, 0, 0])
# label occurrences:  tensor([2, 1, 1, 1])
# ==========================
# K first indices  tensor([16,  4, 12,  5, 18])
# nearest labels:  tensor([1, 2, 0, 0, 0])
# label occurrences:  tensor([3, 1, 1])
# ==========================
# K first indices  tensor([11,  8, 17,  9, 18])
# nearest labels:  tensor([3, 1, 3, 2, 0])
# label occurrences:  tensor([1, 1, 1, 2])
# ==========================
# K first indices  tensor([ 2,  6, 14,  0, 17])
# nearest labels:  tensor([1, 2, 4, 2, 3])
# label occurrences:  tensor([0, 1, 2, 1, 1])
# ==========================
# K first indices  tensor([ 1, 15, 10,  5,  6])
# nearest labels:  tensor([2, 2, 1, 0, 2])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([14, 19,  2,  0, 15])
# nearest labels:  tensor([4, 0, 1, 2, 2])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([ 8,  9,  3, 17, 13])
# nearest labels:  tensor([1, 2, 2, 3, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([7, 3, 9, 0, 8])
# nearest labels:  tensor([3, 2, 2, 2, 1])
# label occurrences:  tensor([0, 1, 3, 1])
# ==========================
# K first indices  tensor([ 2,  0,  6, 17, 14])
# nearest labels:  tensor([1, 2, 2, 3, 4])
# label occurrences:  tensor([0, 1, 2, 1, 1])
# ==========================
# K first indices  tensor([ 3,  8,  7,  9, 17])
# nearest labels:  tensor([2, 1, 3, 2, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([ 3,  8,  9, 17,  7])
# nearest labels:  tensor([2, 1, 2, 3, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([ 1, 15, 10,  5,  6])
# nearest labels:  tensor([2, 2, 1, 0, 2])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([ 2,  0, 14, 19,  7])
# nearest labels:  tensor([1, 2, 4, 0, 3])
# label occurrences:  tensor([1, 1, 1, 1, 1])
# ==========================
# K first indices  tensor([18, 11, 12,  4, 16])
# nearest labels:  tensor([0, 3, 0, 2, 1])
# label occurrences:  tensor([2, 1, 1, 1])
# ==========================
# K first indices  tensor([ 0,  2, 14, 19,  7])
# nearest labels:  tensor([2, 1, 4, 0, 3])
# label occurrences:  tensor([1, 1, 1, 1, 1])
# ==========================
# K first indices  tensor([ 9, 17,  8,  7,  3])
# nearest labels:  tensor([2, 3, 1, 3, 2])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([ 9,  8,  3, 17,  7])
# nearest labels:  tensor([2, 1, 2, 3, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([ 7,  0,  2,  9, 17])
# nearest labels:  tensor([3, 2, 1, 2, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([ 1, 15,  5, 10,  6])
# nearest labels:  tensor([2, 2, 0, 1, 2])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([ 8,  9, 17, 11,  3])
# nearest labels:  tensor([1, 2, 3, 3, 2])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([ 5,  1,  6, 15, 10])
# nearest labels:  tensor([0, 2, 2, 2, 1])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([ 9,  8, 17,  3, 13])
# nearest labels:  tensor([2, 1, 3, 2, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([7, 0, 2, 9, 3])
# nearest labels:  tensor([3, 2, 1, 2, 2])
# label occurrences:  tensor([0, 1, 3, 1])
# ==========================
# K first indices  tensor([ 2,  0, 14,  7,  6])
# nearest labels:  tensor([1, 2, 4, 3, 2])
# label occurrences:  tensor([0, 1, 2, 1, 1])
# ==========================
# K first indices  tensor([ 7,  3,  8,  9, 17])
# nearest labels:  tensor([3, 2, 1, 2, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([14,  2,  0, 19,  6])
# nearest labels:  tensor([4, 1, 2, 0, 2])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([ 9, 17,  2,  8,  7])
# nearest labels:  tensor([2, 3, 1, 1, 3])
# label occurrences:  tensor([0, 2, 1, 2])
# ==========================
# K first indices  tensor([ 9,  8,  3, 17, 13])
# nearest labels:  tensor([2, 1, 2, 3, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([ 4, 12, 18, 13, 17])
# nearest labels:  tensor([2, 0, 0, 3, 3])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([ 6, 13, 16,  5,  4])
# nearest labels:  tensor([2, 3, 1, 0, 2])
# label occurrences:  tensor([1, 1, 2, 1])
# ==========================
# K first indices  tensor([ 6,  2, 13, 17,  5])
# nearest labels:  tensor([2, 1, 3, 3, 0])
# label occurrences:  tensor([1, 1, 1, 2])
# ==========================
# K first indices  tensor([10,  5,  1, 15, 16])
# nearest labels:  tensor([1, 0, 2, 2, 1])
# label occurrences:  tensor([1, 2, 2])
# ==========================
# K first indices  tensor([13,  6, 17,  4, 16])
# nearest labels:  tensor([3, 2, 3, 2, 1])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([15, 14,  1, 19,  2])
# nearest labels:  tensor([2, 4, 2, 0, 1])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([18, 12,  4, 11, 16])
# nearest labels:  tensor([0, 0, 2, 3, 1])
# label occurrences:  tensor([2, 1, 1, 1])
# ==========================
# K first indices  tensor([13,  4, 17, 12,  6])
# nearest labels:  tensor([3, 2, 3, 0, 2])
# label occurrences:  tensor([1, 0, 2, 2])
# ==========================
# K first indices  tensor([13,  4, 17, 12, 18])
# nearest labels:  tensor([3, 2, 3, 0, 0])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([15,  1, 14,  2,  5])
# nearest labels:  tensor([2, 2, 4, 1, 0])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([12, 18,  4, 13, 11])
# nearest labels:  tensor([0, 0, 2, 3, 3])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([ 4, 12, 18, 16, 13])
# nearest labels:  tensor([2, 0, 0, 1, 3])
# label occurrences:  tensor([2, 1, 1, 1])
# ==========================
# K first indices  tensor([12, 18,  4, 16, 13])
# nearest labels:  tensor([0, 0, 2, 1, 3])
# label occurrences:  tensor([2, 1, 1, 1])
# ==========================
# K first indices  tensor([7, 9, 8, 3, 0])
# nearest labels:  tensor([3, 2, 1, 2, 2])
# label occurrences:  tensor([0, 1, 3, 1])
# ==========================
# K first indices  tensor([ 1, 15, 10,  5,  6])
# nearest labels:  tensor([2, 2, 1, 0, 2])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([16,  5,  6, 10,  4])
# nearest labels:  tensor([1, 0, 2, 1, 2])
# label occurrences:  tensor([1, 2, 2])
# ==========================
# K first indices  tensor([17,  9,  2,  8,  7])
# nearest labels:  tensor([3, 2, 1, 1, 3])
# label occurrences:  tensor([0, 2, 1, 2])
# ==========================
# K first indices  tensor([16,  4, 12,  5, 13])
# nearest labels:  tensor([1, 2, 0, 0, 3])
# label occurrences:  tensor([2, 1, 1, 1])
# ==========================
# K first indices  tensor([14, 19,  2,  0, 15])
# nearest labels:  tensor([4, 0, 1, 2, 2])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([ 1, 15, 10,  5,  6])
# nearest labels:  tensor([2, 2, 1, 0, 2])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([19, 14,  0,  2, 15])
# nearest labels:  tensor([0, 4, 2, 1, 2])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([ 5,  1,  6, 15, 10])
# nearest labels:  tensor([0, 2, 2, 2, 1])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([11, 18, 12,  4, 13])
# nearest labels:  tensor([3, 0, 0, 2, 3])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([14, 19, 15,  1,  2])
# nearest labels:  tensor([4, 0, 2, 2, 1])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([10,  5,  1, 15, 16])
# nearest labels:  tensor([1, 0, 2, 2, 1])
# label occurrences:  tensor([1, 2, 2])
# ==========================
# K first indices  tensor([19,  0, 14,  2,  7])
# nearest labels:  tensor([0, 2, 4, 1, 3])
# label occurrences:  tensor([1, 1, 1, 1, 1])
# ==========================
# K first indices  tensor([19, 14,  0,  2, 15])
# nearest labels:  tensor([0, 4, 2, 1, 2])
# label occurrences:  tensor([1, 1, 2, 0, 1])
# ==========================
# K first indices  tensor([ 2,  6, 14,  1, 15])
# nearest labels:  tensor([1, 2, 4, 2, 2])
# label occurrences:  tensor([0, 1, 3, 0, 1])
# ==========================
# K first indices  tensor([11,  8,  9, 17, 18])
# nearest labels:  tensor([3, 1, 2, 3, 0])
# label occurrences:  tensor([1, 1, 1, 2])
# ==========================
# K first indices  tensor([ 5, 10, 16,  6,  1])
# nearest labels:  tensor([0, 1, 1, 2, 2])
# label occurrences:  tensor([1, 2, 2])
# ==========================
# K first indices  tensor([18, 12,  4, 11, 13])
# nearest labels:  tensor([0, 0, 2, 3, 3])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([16,  5,  6, 13,  4])
# nearest labels:  tensor([1, 0, 2, 3, 2])
# label occurrences:  tensor([1, 1, 2, 1])
# ==========================
# K first indices  tensor([ 0,  7,  2, 14, 19])
# nearest labels:  tensor([2, 3, 1, 4, 0])
# label occurrences:  tensor([1, 1, 1, 1, 1])
# ==========================
# K first indices  tensor([ 6,  5,  2,  1, 15])
# nearest labels:  tensor([2, 0, 1, 2, 2])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([ 3,  7,  8,  9, 17])
# nearest labels:  tensor([2, 3, 1, 2, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([ 7,  9, 17,  2,  8])
# nearest labels:  tensor([3, 2, 3, 1, 1])
# label occurrences:  tensor([0, 2, 1, 2])
# ==========================
# K first indices  tensor([ 7,  0,  2,  9, 17])
# nearest labels:  tensor([3, 2, 1, 2, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([18, 12,  4, 13, 11])
# nearest labels:  tensor([0, 0, 2, 3, 3])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([ 0,  2, 14, 19,  7])
# nearest labels:  tensor([2, 1, 4, 0, 3])
# label occurrences:  tensor([1, 1, 1, 1, 1])
# ==========================
# K first indices  tensor([ 9,  8, 17,  3, 13])
# nearest labels:  tensor([2, 1, 3, 2, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([10,  5, 16,  1, 15])
# nearest labels:  tensor([1, 0, 1, 2, 2])
# label occurrences:  tensor([1, 2, 2])
# ==========================
# K first indices  tensor([ 9,  8,  3, 17,  7])
# nearest labels:  tensor([2, 1, 2, 3, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([16,  4, 12, 18, 13])
# nearest labels:  tensor([1, 2, 0, 0, 3])
# label occurrences:  tensor([2, 1, 1, 1])
# ==========================
# K first indices  tensor([13, 17,  4, 12, 18])
# nearest labels:  tensor([3, 3, 2, 0, 0])
# label occurrences:  tensor([2, 0, 1, 2])
# ==========================
# K first indices  tensor([ 0,  7, 19,  2, 14])
# nearest labels:  tensor([2, 3, 0, 1, 4])
# label occurrences:  tensor([1, 1, 1, 1, 1])
# ==========================
# K first indices  tensor([ 6,  5,  1, 15,  2])
# nearest labels:  tensor([2, 0, 2, 2, 1])
# label occurrences:  tensor([1, 1, 3])
# ==========================
# K first indices  tensor([ 6,  5, 13,  2, 16])
# nearest labels:  tensor([2, 0, 3, 1, 1])
# label occurrences:  tensor([1, 2, 1, 1])
# ==========================
# K first indices  tensor([ 9,  8,  3, 17,  7])
# nearest labels:  tensor([2, 1, 2, 3, 3])
# label occurrences:  tensor([0, 1, 2, 2])
# ==========================
# K first indices  tensor([17,  9,  8, 13,  2])
# nearest labels:  tensor([3, 2, 1, 3, 1])
# label occurrences:  tensor([0, 2, 1, 2])
# ==========================
# shape y_test:  tensor([1, 3, 0,  ..., 1, 2, 1])

# %% [markdown]
# We can use the exact same KNN code to perform image classification on CIFAR-10!
#
# Now lets put everything together and test our K-NN clasifier on a subset of CIFAR-10, using k=1:
#
# If you've implemented everything correctly you should see an accuracy of about 27%.

# %%
import torch.nn as nn

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
torch.cuda.memory_summary(device='cuda', abbreviated=True)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 24           |        cudaMalloc retries: 25        |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |  64771 KiB |  14247 MiB | 113299 MiB | 113235 MiB |\n|---------------------------------------------------------------------------|\n| Active memory         |  64771 KiB |  14247 MiB | 113299 MiB | 113235 MiB |\n|---------------------------------------------------------------------------|\n| Requested memory      |  64769 KiB |  14245 MiB | 113287 MiB | 113224 MiB |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |  83968 KiB |  14266 MiB | 113062 MiB | 112980 MiB |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |  19197 KiB | 118343 KiB | 739082 KiB | 719885 KiB |\n|---------------------------------------------------------------------------|\n| Allocations           |       5    |      35    |    4673    |    4668    |\n|---------------------------------------------------------------------------|\n| Active allocs         |       5    |      35    |    4673    |    4668    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |       3    |      13    |      50    |      47    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |       6    |      15    |    1907    |    1901    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %%
from knn import KnnClassifier

torch.manual_seed(0)
num_train = 5000
num_test = 120
x_train, y_train, x_test, y_test = eecs598.data.cifar10(num_train, num_test)

classifier = KnnClassifier(x_train, y_train)
classifier.check_accuracy(x_test, y_test, k=1)
# Out:
# x_train vectorization shape:  torch.Size([5000, 1, 3072])
# x_test vectorization shape:  torch.Size([1, 120, 3072])
# squared_diff shape:  torch.Size([5000, 120, 3072])
# Got 36 / 120 correct; accuracy is 30.00%
# 30.0

# %% [markdown]
# ***Note:***
#
#
# *   with `100` as `num_test` size the ***accuracy*** is `29%`
# *   with `110` as `num_test`  size the ***accuracy*** is `30.91%`
# * with `120` as `num_test` size the ***accuracy*** is `30.0%`
# * with `500` as `num_test` size the ***accuracy*** is `---%`
#
# ***If num_test is above 120 the code crash***

# %% [markdown]
# Now lets increase to k=5. You should see a slightly higher accuracy than k=1:

# %%
from knn import KnnClassifier

torch.manual_seed(0)
num_train = 5000
num_test = 120 #500
x_train, y_train, x_test, y_test = eecs598.data.cifar10(num_train, num_test)

classifier = KnnClassifier(x_train, y_train)
classifier.to(device)
classifier.check_accuracy(x_test, y_test, k=5)
# Out:
# x_train vectorization shape:  torch.Size([5000, 1, 3072])
# x_test vectorization shape:  torch.Size([1, 120, 3072])
# squared_diff shape:  torch.Size([5000, 120, 3072])
# Got 41 / 120 correct; accuracy is 34.17%
# 34.166666666666664

# %% [markdown]
# ***Note:***
#
#
# *   with `150` as `num_test` size the ***accuracy*** is `34.16%`

# %% [markdown]
# ## Cross-validation
# We have not implemented the full k-Nearest Neighbor classifier, but the choice of $k=5$ was arbitrary. We will use **cross-validation** to set this hyperparameter in a more principled manner.
#
# In the file `knn.py`, implement the function `knn_cross_validate` to perform cross-validation on k.

# %%
from knn import knn_cross_validate

torch.manual_seed(0)
num_train = 5000
num_test = 500
x_train, y_train, x_test, y_test = eecs598.data.cifar10(num_train, num_test)

k_to_accuracies = knn_cross_validate(x_train, y_train, num_folds=5)

for k, accs in sorted(k_to_accuracies.items()):
  print('k = %d got accuracies: %r' % (k, accs))

# %%
ks, means, stds = [], [], []
torch.manual_seed(0)
for k, accs in sorted(k_to_accuracies.items()):
  plt.scatter([k] * len(accs), accs, color='g')
  ks.append(k)
  means.append(statistics.mean(accs))
  stds.append(statistics.stdev(accs))
plt.errorbar(ks, means, yerr=stds)
plt.xlabel('k')
plt.ylabel('Cross-validation accuracy')
plt.title('Cross-validation on k')
plt.show()

# %% [markdown]
# Now we can use the results of cross-validation to select the best value for k, and rerun the classifier on our full 5000 set of training examples.
#
# You should get an accuracy above 28%.

# %%
from knn import KnnClassifier
from knn import knn_get_best_k

best_k = 1
torch.manual_seed(0)

best_k = knn_get_best_k(k_to_accuracies)
print('Best k is ', best_k)

classifier = KnnClassifier(x_train, y_train)
classifier.check_accuracy(x_test, y_test, k=best_k)

# %% [markdown]
# Finally, we can use our chosen value of k to run on the entire training and test sets.
#
# This may take a while to run, since the full training and test sets have 50k and 10k examples respectively. You should get an accuracy above 33%.
#
# **Run this only once!**

# %%
from knn import KnnClassifier

torch.manual_seed(0)
x_train_all, y_train_all, x_test_all, y_test_all = eecs598.data.cifar10()
classifier = KnnClassifier(x_train_all, y_train_all)
classifier.check_accuracy(x_test_all, y_test_all, k=best_k)

# %% [markdown]
# ## Submit Your Work
# After completing both notebooks for this assignment (`pytorch101.ipynb` and this notebook, `knn.ipynb`), run the following cell to create a `.zip` file for you to download and turn in. **Please MANUALLY SAVE every `*.ipynb` and `*.py` files before executing the following cell:**

# %%
from eecs598.submit import make_a1_submission

make_a1_submission(GOOGLE_DRIVE_PATH)
